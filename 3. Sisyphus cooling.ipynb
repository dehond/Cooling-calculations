# %%
using QuantumOptics
using WignerSymbols
using LinearAlgebra
using FFTW
using Plots
using LaTeXStrings
pyplot();

# %% [markdown]
# ## Sub-Doppler Sisyphus cooling in a lin$\perp$lin molasses configuration
# It turns out that if we use an atom with a more complicated electronic structe, we get sub-Doppler cooling through polarization gradients for free in this molasses configuration. The simplest level structure that gives rise to this effect is that of a $J = 1/2 \rightarrow J' = 3/2$ transition. If we denote the ground states as $|g_{\pm 1/2}\rangle$ and the excited states as $|e_{\pm 1/2}\rangle, |e_{\pm 3/2}\rangle$, the full Hamiltonian (in the interaction picture, and under the rotating-wave approximation) is given by
#
# \begin{align}
#     \mathcal{H} &= \frac{\Omega}{\sqrt{2}} \left[ \cos(kx) \left( |e_{3/2}\rangle\langle g_{1/2}| + \frac{1}{\sqrt{3}} |e_{1/2}\rangle\langle g_{-1/2}\rangle \right) + \sin(kx) \left( |e_{-3/2}\rangle\langle g_{-1/2}| + \frac{1}{\sqrt{3}} |e_{-1/2}\rangle\langle g_{1/2}| \right) \right] + \mathrm{H.c.} \\
#                 &\qquad - \delta \sum_e |e\rangle\langle e|,
# \end{align}
#
# where the sum runs over all excited states $|e\rangle$. The lin$\perp$lin configuration can also be understood as consisting of two standing waves of $\sigma_-$ and $\sigma_+$ polarization, shifted 90$^\circ$ out of phase with respect to each other. We used this in the Hamiltonian above, where the terms preceded by $\cos$ ($\sin$) denote couplings by the $\sigma_+$ ($\sigma_-$) light. In a two-level system, the Rabi frequency $\Omega$ would have a prefactor of $1/2$. Here we have two beams with linearly polarized light, though. A single beam carries a 'Rabi frequency' of $\Omega/\sqrt{2}$ per polarization (since $\Omega$ is proportional to the electric field). When we add two beams add together, this leaves a prefactor of $2/2\sqrt{2} = 1/\sqrt{2}$.
#
# #### Units
# In cooling calculations it's convenient to express all frequencies in units of $\Gamma$, the natural line width, and any distances in units of $1/k$, also known as $ƛ$. This means velocities are given in units of $\Gamma/k$. Furthermore, we have chosen atomic units (by setting $\hbar = 1$), which means forces are readily expressed in units of $\hbar k \Gamma$.

# %%
δ = -1.;
Ω = 0.3;
s₀ = 2 * Ω^2;

# %% [markdown]
# ### Set up the basis
# Because no default basis of QuantumOptics.jl is good for us, we'll just use a `GenericBasis` with the requisite number of states.

# %%
Fg = 1/2;
Fe = 3/2;
nStates = Int(2*(Fg + Fe) + 2);
gStates= [[Fg, mFg] for mFg in [-Fg:Fg;]];
eStates = [[Fe, mFe] for mFe in [-Fe:Fe;]];
states = [gStates; eStates];
sbasis = GenericBasis(nStates);

# %% [markdown]
# Calculate the couplings, and use them to calculate the matrix elements corresponding to the individual beams. We iterate over all possible states, and calculate the Clebsch-Gordan coefficients to find out which states couple to which, and with what strength. We will also use the fact that in this configuration we have standing waves of $\sigma_-$ and $\sigma_+$ polarization, which are out of phase by 90$^\circ$ (or a $\sin$ and a $\cos$). The iterators `i` and `j` run over all ground and excited states, respectively. They are used to keep track of the position a particular matrix element would correspond to. The corresponding Clebsch-Gordan coefficient is calculated, and added to the same array. We do this for both $\sigma_-$ and $\sigma_+$ couplings.

# %%
σmincoupling = [[[j+(2*Fg + 1) i 1. * clebschgordan(gStates[i][1], gStates[i][2], 1, -1, eStates[j][1], eStates[j][2] )] for i in [1:Int(2*Fg + 1);]] for j in [1:Int(2*Fe + 1);]];
σmincoupling = collect(Iterators.flatten(σmincoupling));

σpluscoupling = [[[j+(2*Fg + 1) i 1. * clebschgordan(gStates[i][1], gStates[i][2], 1, 1, eStates[j][1], eStates[j][2] )] for i in [1:Int(2*Fg + 1);]] for j in [1:Int(2*Fe + 1);]];
σpluscoupling = collect(Iterators.flatten(σpluscoupling));

# %%
VminMat = vcat(σmincoupling...);
Vminhalf = Ω / √(2) * SparseOperator(sbasis, complex(sparse(VminMat[:, 1], VminMat[:, 2], VminMat[:, 3], nStates, nStates)) );
Vmintot(z) = sin(z) * (Vminhalf + dagger(Vminhalf) );

VplusMat = vcat(σpluscoupling...);
Vplushalf = Ω / √(2) * SparseOperator(sbasis, complex(sparse(VplusMat[:, 1], VplusMat[:, 2], VplusMat[:, 3], nStates, nStates)) );
Vplustot(z) = cos(z) * (Vplushalf + dagger(Vplushalf) );

# %% [markdown]
# Define the Hamiltonian and force. The latter is defined clasically as
# $$
#     F = -\langle \nabla\mathcal{H} \rangle.
# $$

# %%
diagonalTerm = SparseOperator(sbasis, complex(Matrix(Diagonal([zeros(Int(2*Fg + 1)); ones(Int(2*Fe + 1))]))));

# %%
H(z) = Vmintot(z) + Vplustot(z) - δ * diagonalTerm;
F(z) = - cos(z) * ( Vminhalf + dagger(Vminhalf) ) + sin(z) * ( Vplushalf + dagger(Vplushalf) );

# %% [markdown]
# ### Decay, dephasing, and jump operators
# The full evolution of the density matrix $\rho$ is given by the master equation
# $$
#     i\frac{d\rho}{dt} = \left[\mathcal{H}, \rho \right] + \sum_L L\rho L^\dagger - \frac{1}{2} \left\{ L^\dagger L, \rho \right\}.
# $$
# where $L$ are the quantum jump operators. Due to our choice of units, they must be defined such that the sum of the squares of their elements equals unity. We don't really need to bother with this master equation itself, since QuantumOptics.jl will do it for us.
#
# We obtain the quantum jump operators by iterating over all the possible couplings, and using those with nonzero Clebsch-Gordan coefficients. To that extent, we need the couplings by $\pi$ photons as well. Decay paths with the same polarization are combined into a single jump operator.

# %%
πcoupling = [[[j+(2*Fg + 1) i 1. * clebschgordan(gStates[i][1], gStates[i][2], 1, 0, eStates[j][1], eStates[j][2] )] for i in [1:Int(2*Fg + 1);]] for j in [1:Int(2*Fe + 1);]];
πcoupling = collect(Iterators.flatten(πcoupling));

L = [];

# Loop over all excited states, and find paths down
for couplings in (σmincoupling, σpluscoupling, πcoupling)
    cpls = vcat(couplings...);
    
    # Combine all decays with a particular polarization into one jump operator (select nonzero elements)
    cpls = cpls[ cpls[:, 3] .> 0., : ]
    
    # Construct the jump operator describing that decay
    L = vcat(L, SparseOperator(sbasis, sparse(cpls[:, 2], cpls[:, 1], complex(cpls[:, 3]), nStates, nStates)));
end

rate = ones(3);
Ldagger = dagger.(L);

# %% [markdown]
# ### Setting up the time evolution and force calculation

# %% [markdown]
# There's somewhat of a conversion issue: because we enforce constant velocity, there is no such thing as a steady state. This is always the case when cooling off of a standing wave, so then the force is the average force over one cycle. We need to run the calculation long enough for the atom to go through one cycle, so that we can take a proper average (if we don't do this, we get a weird aphysical divergence in the result). We wil have sampled at least one cycle if $T_\mathrm{max} \gg 2\pi/kv$. Some tinkering shows that a good end time is $16\pi / kv$. If some divergences occur for small velocities anyway, change the `maxtime` in the function below. This is an upper limit to the simulation time, if we can run it for a shorter time, we do so. We also introduce a minimum simulation time (`mintime`) because otherwise we do not capture the high velocity behavior ($v \sim 1$) well, where the force is purely due to Doppler cooling.
#
# We find the average by taking the Fourier transform of the force during the second half of the time evolution. The first Fourier coefficient is then proportional to the average force. This works better then simply taking the minimum and maximum of the peaks, because in the sub-Doppler part there are multiple frequency components at work.

# %%
function ForceFromFFT(Fexpect)
    npoints = length(Fexpect);
    f = fft( Fexpect ) / npoints;
    return real(f[1])
end;

# %%
ψ₀ = Ket(sbasis, sqrt.([0.5; 0.5; zeros(nStates - 2)]));
mintime = 500;
maxtime = 50000;

function force(v)
    Tₘ = 32*π / abs(v);
    Tₘ = max(mintime, min(maxtime, Tₘ));
    T = [0 : 0.1 : Tₘ;];
    Hₜ = (t, ρ) -> (H(v * t), L, Ldagger);
    tout, ρₜ = timeevolution.master_dynamic(T, ψ₀, Hₜ; rates = rate);
    Fexpect = real(expect.(F.(tout * v), ρₜ))
    return ForceFromFFT(Fexpect);
end;

# %% [markdown]
# #### Run and plot

# %%
vmin = 32*π / maxtime;         # The lowest velocity we can use such that the evolution converges within maxtime
vs = ([-1:0.01:1;].^3)*2;      # Set up such that we sample a little denser around v = 0
vs = vs[ abs.(vs) .> vmin];    # Remove the velocities for which we do not run the evolution long enough
forces = force.(vs);

# %%
plot(vs, 2*forces,
    width = 2,
    ylim = (-0.2, 0.2),
    xlabel = L"$v$ [$\Gamma$/k]",
    ylabel = L"$F$ [$\hbar k\Gamma/2$]",
    frame = true,
    xtickfont = font(15),
    ytickfont = font(15),
    xaxis = font(18),
    yaxis = font(18),
    label = "")

# %% [markdown]
# Compare this to Fig. 7 from the [paper by Jean Dalibard and Claude Cohen-Tannoudji](https://www.osapublishing.org/josab/abstract.cfm?uri=josab-6-11-2023) (we included an extra factor of 2 to make sure the units of the y axes agree):

# %% [markdown]
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Steady state convergence & behavior
# How does the system converge to the steady state, and what are the population distributions there? Here we can check whether the time limits set in the calculation above are good enough.

# %%
vᵤ = -0.005;
ψ₀ = Ket(sbasis, sqrt.([0.5; 0.5; zeros(nStates - 2)]));
Tₘ = 32*π / abs(vᵤ);
T = [0:0.01:Tₘ;];
Hₜ = (t, ρ) -> (H(vᵤ * t), L, Ldagger);
tout, ρₜ = timeevolution.master_dynamic(T, ψ₀, Hₜ; rates = rate);

# %%
plot(tout, real(expect(DenseOperator(sbasis, Diagonal([1.; zeros(nStates - 1)])), ρₜ)), label = L"$\langle g_{-1/2} | \rho | g_{-1/2} \rangle$", width = 2)
plot!(tout, real(expect(DenseOperator(sbasis, Diagonal([0.; 1.; zeros(nStates - 2)])), ρₜ)), label = L"$\langle g_{1/2} | \rho | g_{1/2} \rangle$",
    frame = true,
    width = 2,
    xlabel = L"$t$ [$1/\Gamma$]",
    xtickfont = font(15),
    ytickfont = font(15),
    xaxis = font(18),
    yaxis = font(18),
    legendfont = font(12))
